# %%
import pandas as pd
dataset = pd.read_csv("sample.csv",encoding="utf")
dataset.columns = ["query_id","query","title","label"]
dataset
# Out:
#       query_id            query  \
# 0            1       100 平方 设计图
# 1            1       100 平方 设计图
# 2            2     100 款 电视 背景墙
# 3            2     100 款 电视 背景墙
# 4            2     100 款 电视 背景墙
# 5            2     100 款 电视 背景墙
# 6            4      16 35 gm 香港
# 7            4      16 35 gm 香港
# 8            5          1650 ti
# 9            5          1650 ti
# 10           6   168 高 的 花季 美少女
# 11           6   168 高 的 花季 美少女
# 12           6   168 高 的 花季 美少女
# 13           7         1999 大阅兵
# 14           7         1999 大阅兵
# 15           8  2 年内 嫁 了 7 个 老公
# 16           8  2 年内 嫁 了 7 个 老公
# 17           8  2 年内 嫁 了 7 个 老公
# 18           9        200w 人 游荡
# 19           9        200w 人 游荡
# 20          10     2017 央视 元宵晚会
# 21          10     2017 央视 元宵晚会
# 22          11      2017年 江西 中考
# 23          11      2017年 江西 中考
# 24          11      2017年 江西 中考
# 25          11      2017年 江西 中考
# 26          12   2017年 江西 中考 数学
# 27          12   2017年 江西 中考 数学
# ...
